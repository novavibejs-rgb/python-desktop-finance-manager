# %%
import banco.banco as banco

# %%
banco.buscar_dados_socio(12)

# %%
from serviços.email_service import ServicoEmail
