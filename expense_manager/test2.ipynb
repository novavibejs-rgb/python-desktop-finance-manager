# %%
from finance_manager import Financeiro

# %%
fm = Financeiro()

# %%
fm.obter_total_bruto()
# Out:
# 0

# %%
fm.adicionar_servico("carro", 500)
# Out:
# {'id': 1,
#  'data': '2026-05-30T21:49:14.545896',
#  'descricao': 'carro',
#  'valor_bruto': 500,
#  'reserva': 100.0,
#  'lucro': 400.0}

# %%
fm.obter_saldo_socio("jeanderson")
# Out:
# 200.0

# %%
fm.obter_total_reserva()
# Out:
# 100.0
